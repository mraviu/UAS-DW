# %%
import pandas as pd
import sqlite3
import math 
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from IPython.core.display import display, HTML

# %%
import sqlite3

conn = sqlite3.connect('datasets_435_896_sales_data_sample.db')

# %%
c = conn.cursor()

# %%
import numpy as np
import cv2
img = cv2.imread ( 'DATA.jpg',0  )
img = cv2.imread ( 'DATA.png',0  )
img = cv2.imread ( 'DATA.png',0  )
cv2.imshow ( 'DATA' , img )
k = cv2.waitKey (0) & 0xFF
if k == 27 :
    cv2.destroyAllWindows ()
elif k == ord ( 's' ): 
    cv2.imwrite ( 'contohgray.png' , img )
    cv2.destroyAllWindows ()

# %%
import numpy as np
import cv2
img = cv2.imread ( 'design.jpg',0  )
img = cv2.imread ( 'design.png',0  )
img = cv2.imread ( 'design.png',0  )
cv2.imshow ( 'DATA' , img )
k = cv2.waitKey (0) & 0xFF
if k == 27 :
    cv2.destroyAllWindows ()
elif k == ord ( 's' ): 
    cv2.imwrite ( 'contohgray.png' , img )
    cv2.destroyAllWindows ()

# %%
import pandas as pd

df = pd.DataFrame({
    
            'CUSTOMERNAME':['Land of Toys Inc,Reims Collectables','Lyon Souveniers','Toys4GrownUps.com','Corporate Gift Ideas Co','Technics Stores Inc.'],
            'PRODUCTLINE' :['Motorcycles','Motorcycles','Motorcycles','Motorcycles','Motorcycles'],
            'ADDRESSLINE1':[' Long Airport Avenue','rue de l','Abbaye','rue du Colonel Pierre Avia','Hillside Dr'],
            'PHONE':['2125557818','26.47.1555','33 1 46 62 7555','6265557265','6505551386'],
            
    })
df
# Out:
#                  ADDRESSLINE1                         CUSTOMERNAME  \
# 0         Long Airport Avenue  Land of Toys Inc,Reims Collectables
# 1                    rue de l                      Lyon Souveniers
# 2                      Abbaye                    Toys4GrownUps.com
# 3  rue du Colonel Pierre Avia              Corporate Gift Ideas Co
# 4                 Hillside Dr                 Technics Stores Inc.
#
#              PHONE  PRODUCTLINE
# 0       2125557818  Motorcycles
# 1       26.47.1555  Motorcycles
# 2  33 1 46 62 7555  Motorcycles
# 3       6265557265  Motorcycles
# 4       6505551386  Motorcycles

# %%
import csv

datasets_435_896_sales_data_sample = [ 
    ( 1, '10107', "30", "95.7", "2", "2871", "2/24/2003 0:00", "Shipped", "1", "2", "2003", "Motorcycles", "95", "S10_1678", "Land of Toys Inc.", "2125557818", "897 Long Airport Avenue", "-", "NYC", "NY", "10022", "USA", "NA", "Yu", "Kwai", "Small"),
    ( 2, '10121', "34", "81.35", "5", "2765.9", "05/07/2003 00:00", "Shipped", "2", "5", "2003", "Motorcycles", "95", "S10_1678", "Reims Collectables", "26.47.1555", "59 rue de l'Abbaye", "-", "Reims", "-", "51100", "France", "EMEA", "Henriot", "Paul", "Small"),
TR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY' , 'TERRITORY', 'CONTACTLASTNAME','CONTACTFIRSTNAME', 'DEALSIZE'))

for s in datasets_435_896_sales_data_sample:
    w.writerow(s)

f.close()

# %%
import pandas as pd

f = pd.read_csv("datasets_435_896_sales_data_sample.csv")
f
# Out:
#    No  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0   1        10107               30      95.70                2  2871.00
# 1   2        10121               34      81.35                5  2765.90
# 2   3        10134               41      94.74                2  3884.34
# 3   4        10145               45      83.26                6  3746.70
# 4   5        10159               49     100.00               14  5205.27
# 5   6        10168               36      96.66                1  3479.76
# 6   7        10180               29      86.13                9  2497.77
# 7   8        10188               48     100.00                1  5512.32
# 8   9        10201               22      98.57                2  2168.54
# 9  10        10211               41     100.00               14  4708.44
#
#           ORDERDATE     STATUS  QTR_ID  MONTH_ID   ...     \
# 0    2/24/2003 0:00    Shipped       1         2   ...
# ...

# %%
import pandas as pd
#importing the dataset
datasets_435_896_sales_data_sample = pd.read_csv('datasets_435_896_sales_data_sample.csv')
datasets_435_896_sales_data_sample
# Out:
#    No  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0   1        10107               30      95.70                2  2871.00
# 1   2        10121               34      81.35                5  2765.90
# 2   3        10134               41      94.74                2  3884.34
# 3   4        10145               45      83.26                6  3746.70
# 4   5        10159               49     100.00               14  5205.27
# 5   6        10168               36      96.66                1  3479.76
# 6   7        10180               29      86.13                9  2497.77
# 7   8        10188               48     100.00                1  5512.32
# 8   9        10201               22      98.57                2  2168.54
# 9  10        10211               41     100.00               14  4708.44
#
#           ORDERDATE     STATUS  QTR_ID  MONTH_ID   ...     \
# 0    2/24/2003 0:00    Shipped       1         2   ...
# ...

# %%
#displaying the dataset
datasets_435_896_sales_data_sample.head(5)
# Out:
#    No  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0   1        10107               30      95.70                2  2871.00
# 1   2        10121               34      81.35                5  2765.90
# 2   3        10134               41      94.74                2  3884.34
# 3   4        10145               45      83.26                6  3746.70
# 4   5        10159               49     100.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID   ...     \
# 0    2/24/2003 0:00  Shipped       1         2   ...
# 1  05/07/2003 00:00  Shipped       2         5   ...
# 2  07/01/2003 00:00  Shipped       3         7   ...
# 3    8/25/2003 0:00  Shipped       3         8   ...
# 4  10/10/2003 00:00  Shipped       4        10   ...
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue            -            NYC    NY      10022
# ...

# %%
import pandas as pd
datasets_435_896_sales_data_sample.dtypes
# Out:
# No                    int64
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID              object
# PRODUCTLINE          object
# MSRP                 object
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object
